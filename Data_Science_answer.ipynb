# %%
#1
import pandas as pd
import matplotlib.pyplot as plt
tt = pd.read_csv('mask-use-by-county.csv')
tt.head(3)
tt.tail(3)
tt.loc[4:7]
plt.figure()
tt['NEVER'].hist(bins=10)
plt.figure()
tt['RARELY'].hist(bins=10)
plt.figure()
tt['SOMETIMES'].hist(bins=10)
# Out:
# <AxesSubplot:>
